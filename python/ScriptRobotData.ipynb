# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_flie = pd.read_csv(os.path.join("data", "RobotDataStrategy2.csv"))
csv_flie
# Out:
#          nanoTime  sensorValue1  sensorValue2  sensorValue3  sensorValue4  \
# 0    128035814014          4081          4081          4079          4079
# 1    128138222058          4081          4082          4083          4079
# 2    128193439613          4081          4079          4078          4079
# 3    128250071800          4081          4079          4078          4079
# 4    128310726696          4082          4079          4082          4080
# ..            ...           ...           ...           ...           ...
# 165  136799095863          4082          4081          4082          4082
# 166  136850149552          4081          4081          4083          4079
# 167  136902105241          4081          4081          4083          4079
# 168  136953099711          4081          4081          4082          4079
# 169  137004061275          4078          4079          4079          4078
#
#      sensorValue5      xPos      yPos     theta  rawAngle1  rawAngle2  \
# ...

# %%
plt.plot(csv_flie["xPos"],csv_flie["yPos"])
