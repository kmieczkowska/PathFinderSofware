# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_flie = pd.read_csv(os.path.join("data", "RobotData.csv"))
csv_flie
# Out:
#            nanoTime  sensorValue1  sensorValue2  sensorValue3  sensorValue4  \
# 0    11670373533000          4040          4063          4071          4052
# 1    11670443377300          4039          4063          4072          4053
# 2    11670504671900          4039          4063          4071          4053
# 3    11670567163500          4040          4064          4072          4052
# 4    11670631035100          4039          4063          4073          4052
# ..              ...           ...           ...           ...           ...
# 166  11680723057800          4039          4063          4072          4052
# 167  11680786160300          4039          4063          4072          4053
# 168  11680847611200          4039          4064          4071          4053
# 169  11680909602300          4041          4065          4071          4053
# 170  11680972768600          4039          4065          4071          4053
#
# ...

# %%
# Out:
# 0      0.009456
# 1      0.009456
# 2      0.009476
# 3      0.009476
# 4      0.009476
#          ...
# 166    0.032172
# 167    0.032754
# 168    0.033409
# 169    0.033843
# 170    0.034195
# Name: xPos, Length: 171, dtype: float64

# %%
plt.plot(csv_flie["xPos"],csv_flie["yPos"])
